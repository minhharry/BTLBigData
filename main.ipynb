# %%
import pandas as pd

# %%
df = pd.read_csv('data/observations-2026-4-3.csv')

# %%
df['phenomenonTime'] = pd.to_datetime(df['phenomenonTime'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1808301 entries, 0 to 1808300
# Data columns (total 17 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   id                                 str
#  1   samplingPoint.notation             str
#  2   samplingPoint.prefLabel            str
#  3   samplingPoint.longitude            float64
#  4   samplingPoint.latitude             float64
#  5   samplingPoint.region               str
#  6   samplingPoint.area                 str
#  7   samplingPoint.subArea              str
#  8   samplingPoint.samplingPointStatus  str
#  9   samplingPoint.samplingPointType    str
#  10  phenomenonTime                     datetime64[us]
#  11  samplingPurpose                    str
#  12  sampleMaterialType                 str
#  13  determinand.notation               int64
#  14  determinand.prefLabel              str
#  15  result                             str
# ...

# %%
df.sort_values('phenomenonTime').to_csv('data/observations-2026-4-3-sorted.csv', index=False)
